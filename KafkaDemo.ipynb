# %% [markdown]
# # Kafka Demo — Lab 3
#
# ### Connect to Kafka Broker Server
# Open an SSH tunnel in your terminal and leave it running while you use this notebook.
# Replace `<NetID>` with your UIC NetID:
# ```
# ssh -o ServerAliveInterval=60 -L 9092:localhost:9092 <NetID>@cs544-f26.cs.uic.edu -NTf
# ```
#
# ### To kill connection
# ```
# lsof -ti:9092 | xargs kill -9
# ```
#
# ### Setup
# ```
# python -m pip install kafka-python
# ```
#
# See [bug_list.md](./bug_list.md) for frequent bugs and solutions.

# %%
import os
from datetime import datetime
from json import dumps, loads
from time import sleep
from random import randint
from kafka import KafkaConsumer, KafkaProducer

# Update this for your own recitation section :)
topic = 'recitation-x' # replace x with your recitation section

# %% [markdown]
# ### Producer Mode -> Writes Data to Broker

# %%
# Create a producer to write data to kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaProducer.html

# [TODO]: Replace '...' with the address of your Kafka bootstrap server
producer = KafkaProducer(bootstrap_servers=["localhost:9092"],
                        value_serializer=lambda x: dumps(x).encode('utf-8'))

# [TODO]: Add cities of your choice
cities = ["Chicago", "New York", "Istanbul"]

# Write data via the producer
print("Writing to Kafka Broker")
for i in range(10):
    data = f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")},{cities[randint(0,len(cities)-1)]},{randint(18, 32)}ºC'
    print(f"Writing: {data}")
    producer.send(topic=topic, value=data)
    sleep(1)
# Out:
# Writing to Kafka Broker
# Writing: 2026-09-24 12:32:40,New York,32ºC
# Writing: 2026-09-24 12:32:41,Chicago,25ºC
# Writing: 2026-09-24 12:32:42,Chicago,32ºC
# Writing: 2026-09-24 12:32:43,Chicago,25ºC
# Writing: 2026-09-24 12:32:44,New York,28ºC
# Writing: 2026-09-24 12:32:45,New York,23ºC
# Writing: 2026-09-24 12:32:46,Chicago,25ºC
# Writing: 2026-09-24 12:32:47,Istanbul,30ºC
# Writing: 2026-09-24 12:32:48,Chicago,28ºC
# Writing: 2026-09-24 12:32:49,Istanbul,27ºC

# %% [markdown]
# ### Consumer Mode -> Reads Data from Broker

# %%
# Create a consumer to read data from kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaConsumer.html

# [TODO]: Complete the missing ... parameters/arguments using the Kafka documentation
consumer = KafkaConsumer(
    topic,
    bootstrap_servers=["localhost:9092"],
    auto_offset_reset="earliest", #Experiment with different values
    # Commit that an offset has been read
    enable_auto_commit=True,
    # How often to tell Kafka, an offset has been read
    auto_commit_interval_ms=1000
)

print('Reading Kafka Broker')
for message in consumer:
    message = message.value.decode()
    # Default message.value type is bytes!
    print(loads(message))
    os.system(f"echo {message} >> kafka_log.csv")
# Out:
# Reading Kafka Broker
# 2026-09-23 18:06:18,chicago,30ºC
# 2026-09-23 18:06:20,chicago,28ºC
# 2026-09-23 18:06:21,san diego,21ºC
# 2026-09-23 18:06:22,san diego,28ºC
# 2026-09-23 18:06:23,san diego,27ºC
# 2026-09-23 18:06:24,chicago,30ºC
# 2026-09-23 18:06:25,phoenix,30ºC
# 2026-09-23 18:06:26,san diego,29ºC
# 2026-09-23 18:06:27,chicago,21ºC
# 2026-09-23 18:06:28,san diego,30ºC
# 2026-09-23 18:29:45,phoenix,31ºC
# 2026-09-23 18:29:46,phoenix,21ºC
# 2026-09-23 18:29:47,san diego,26ºC
# 2026-09-24 12:47:11,phoenix,31ºC
# 2026-09-24 12:50:55,chicago,29ºC
# 2026-09-24 12:50:57,san diego,25ºC
# 2026-09-24 12:50:58,phoenix,21ºC
# 2026-09-24 12:50:59,phoenix,22ºC
# 2026-09-24 12:51:00,phoenix,29ºC
# 2026-09-24 12:51:01,chicago,19ºC
# 2026-09-24 12:51:02,phoenix,28ºC
# 2026-09-24 12:51:03,chicago,19ºC
# 2026-09-24 12:51:04,phoenix,26ºC
# 2026-09-24 12:51:05,phoenix,32ºC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 16
#       5 consumer = KafkaConsumer(
#       6     topic,
#       7     bootstrap_servers=["localhost:9092"],
#    (...)
#      12     auto_commit_interval_ms=1000
#      13 )
#      15 print('Reading Kafka Broker')
# ---> 16 for message in consumer:
#      17     message = message.value.decode()
#      18     # Default message.value type is bytes!
#
# File /opt/anaconda3/lib/python3.12/site-packages/kafka/consumer/group.py:1358, in KafkaConsumer.__next__(self)
#    1356     self._iterator = self._message_generator_v2()
#    1357 try:
# -> 1358     return next(self._iterator)
#    1359 except StopIteration:
#    1360     self._iterator = None
#
# File /opt/anaconda3/lib/python3.12/site-packages/kafka/consumer/group.py:1329, in KafkaConsumer._message_generator_v2(self)
#    1327 def _message_generator_v2(self):
#    1328     timeout_ms = 1000 * max(0, self._consumer_timeout - time.monotonic())
# -> 1329     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1330     for tp, records in record_map.items():
#    1331         # Generators are stateful, and it is possible that the tp / records
#    1332         # here may become stale during iteration -- i.e., we seek to a
#    1333         # different offset, pause consumption, or lose assignment.
#    1334         for record in records:
#    1335             # is_fetchable(tp) should handle assignment changes and offset
#    1336             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1337             # outer function destroying the existing iterator/generator
#    1338             # via self._iterator = None
#
# File /opt/anaconda3/lib/python3.12/site-packages/kafka/consumer/group.py:827, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     825 timer = Timer(timeout_ms)
#     826 while not self._closed:
# --> 827     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     828     if records:
#     829         return records
#
# File /opt/anaconda3/lib/python3.12/site-packages/kafka/consumer/group.py:865, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     862 if self.config['group_id'] is not None:
#     863     poll_timeout_ms = min(poll_timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 865 records, idle = self._fetcher.fetch_records(
#     866     max_records, update_offsets=update_offsets, timeout_ms=poll_timeout_ms)
#     867 if not records and idle and poll_timeout_ms > 0:
#     868     # Nothing fetchable and nothing in flight (no assignment, all
#     869     # paused, or no resolvable positions). Sleep up to poll_timeout_ms
#     870     # to avoid busy-looping; poll_timeout_ms is already capped by the
#     871     # coordinator's next-action deadline.
#     872     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
#
# File /opt/anaconda3/lib/python3.12/site-packages/kafka/consumer/fetcher.py:261, in Fetcher.fetch_records(self, max_records, update_offsets, timeout_ms)
#     258     fut.add_both(_wake)
#     260 try:
# --> 261     self._net.run(self._manager.wait_for, wakeup, timeout_ms)
#     262 except Errors.KafkaTimeoutError:
#     263     pass
#
# File /opt/anaconda3/lib/python3.12/site-packages/kafka/net/selector.py:330, in NetworkSelector.run(self, coro, *args)
#     328     self._pending_waiters[event] = state
#     329 self.call_soon_threadsafe(waiter)
# --> 330 event.wait()
#     331 if state['exception'] is not None:
#     332     raise state['exception']  # pylint: disable=E0702
#
# File /opt/anaconda3/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /opt/anaconda3/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Use kcat!
# It's a CLI (Command Line Interface). Previously known as kafkacat
#
#
# Ref: https://docs.confluent.io/platform/current/app-development/kafkacat-usage.html

# %%
#kcat command: connect to local Kafka broker, specify a topic, and consume messages from the earliest offset
